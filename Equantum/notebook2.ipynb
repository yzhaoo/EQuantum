# %%
import scipy.constants as sc

# %%
0.9*sc.h/sc.e/(0.023*1e-6)**2
# Out:
# 7.036107612913939

# %%
2*sc.hbar*1e6/(3*(1*1e-9))/sc.elementary_charge
# Out:
# 0.43880797130060434

# %%
2/5.2387608725728265e-20/1e16
# Out:
# 3817.69668180669

# %%
0.142**2
# Out:
# 0.020163999999999998

# %%
def E_to_n(ee,phi,a):
    """
    traslate the energy (in the unit of the hopping amplitude) to the carrier density (in the unit of 10^12 cm^-2) according to the LL energy of graphene
    """
    return (ee**2/(3*np.pi)+4*phi/np.sqrt(3))/(3* a**2)/1e16
